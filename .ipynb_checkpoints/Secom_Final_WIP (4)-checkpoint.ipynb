# %% [markdown]
# # Step 1:Loading and Merging The dataset

# %%
#Load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from scipy.stats import shapiro
from sklearn.impute import SimpleImputer, KNNImputer


#Load the datasets

url1 ='https://archive.ics.uci.edu/ml/machine-learning-databases/secom/secom.data'
names = ["feature" + str(x) for x in range(1, 591)]
df1 = pd.read_csv(url1,sep=" ", names=names, na_values = "NaN",header=None)
df1.head()

url2 ='https://archive.ics.uci.edu/ml/machine-learning-databases/secom/secom_labels.data'
df2 = pd.read_csv(url2,sep=" ",names = ["Result","Date"])
#df2.columns =['Pass/Fail','Date']
df2.head()



#Convertion of Date into Datetime from Object(String) data types
df2['Date'] = pd.to_datetime(df2['Date'])
df2.dtypes



#Joinig TWO df1 and df2 Dataframe naming SECOM
Secom = pd.concat([df1,df2],axis = 1)
print(Secom)



#We consider datetime donot have an important effect of whether a test fails or not.so dropping this column.
Secom = Secom.drop(['Date'],axis=1)
  
    
    
# establish target and features of the manufacturing data
# set the target to the encoded manufacturing outcome column

y = Secom[['Result']]



# set the features from sensors and putting in x 

x = Secom.drop(['Result'], axis=1)



# getting the shapes of new data sets x and y

print("shape of x:", x.shape)
print("shape of y:", y.shape)
# Out:
#       feature1  feature2   feature3   feature4  feature5  feature6  feature7  \
# 0      3030.93   2564.00  2187.7333  1411.1265    1.3602     100.0   97.6133
# 1      3095.78   2465.14  2230.4222  1463.6606    0.8294     100.0  102.3433
# 2      2932.61   2559.94  2186.4111  1698.0172    1.5102     100.0   95.4878
# 3      2988.72   2479.90  2199.0333   909.7926    1.3204     100.0  104.2367
# 4      3032.24   2502.87  2233.3667  1326.5200    1.5334     100.0  100.3967
# ...        ...       ...        ...        ...       ...       ...       ...
# 1562   2899.41   2464.36  2179.7333  3085.3781    1.4843     100.0   82.2467
# 1563   3052.31   2522.55  2198.5667  1124.6595    0.8763     100.0   98.4689
# 1564   2978.81   2379.78  2206.3000  1110.4967    0.8236     100.0   99.4122
# 1565   2894.92   2532.01  2177.0333  1183.7287    1.5726     100.0   98.7978
# 1566   2944.92   2450.76  2195.4444  2914.1792    1.5978     100.0   85.1011
#
#       feature8  feature9  feature10  ...  feature583  feature584  feature585  \
# 0       0.1242    1.5005     0.0162  ...      0.5005      0.0118      0.0035
# 1       0.1247    1.4966    -0.0005  ...      0.5019      0.0223      0.0055
# 2       0.1241    1.4436     0.0041  ...      0.4958      0.0157      0.0039
# 3       0.1217    1.4882    -0.0124  ...      0.4990      0.0103      0.0025
# 4       0.1235    1.5031    -0.0031  ...      0.4800      0.4766      0.1045
# ...        ...       ...        ...  ...         ...         ...         ...
# 1562    0.1248    1.3424    -0.0045  ...      0.4988      0.0143      0.0039
# 1563    0.1205    1.4333    -0.0061  ...      0.4975      0.0131      0.0036
# 1564    0.1208       NaN        NaN  ...      0.4987      0.0153      0.0041
# 1565    0.1213    1.4622    -0.0072  ...      0.5004      0.0178      0.0038
# 1566    0.1235       NaN        NaN  ...      0.4987      0.0181      0.0040
#
#       feature586  feature587  feature588  feature589  feature590  Result  \
# 0         2.3630         NaN         NaN         NaN         NaN      -1
# 1         4.4447      0.0096      0.0201      0.0060    208.2045      -1
# 2         3.1745      0.0584      0.0484      0.0148     82.8602       1
# 3         2.0544      0.0202      0.0149      0.0044     73.8432      -1
# 4        99.3032      0.0202      0.0149      0.0044     73.8432      -1
# ...          ...         ...         ...         ...         ...     ...
# 1562      2.8669      0.0068      0.0138      0.0047    203.1720      -1
# 1563      2.6238      0.0068      0.0138      0.0047    203.1720      -1
# 1564      3.0590      0.0197      0.0086      0.0025     43.5231      -1
# 1565      3.5662      0.0262      0.0245      0.0075     93.4941      -1
# 1566      3.6275      0.0117      0.0162      0.0045    137.7844      -1
#
#                     Date
# 0    2008-07-19 11:55:00
# 1    2008-07-19 12:32:00
# 2    2008-07-19 13:17:00
# 3    2008-07-19 14:43:00
# 4    2008-07-19 15:22:00
# ...                  ...
# 1562 2008-10-16 15:13:00
# 1563 2008-10-16 20:49:00
# 1564 2008-10-17 05:26:00
# 1565 2008-10-17 06:01:00
# 1566 2008-10-17 06:07:00
#
# [1567 rows x 592 columns]
# shape of x: (1567, 590)
# shape of y: (1567, 1)

# %% [markdown]
# # Step 2: Splitting the dataset

# %%
#Splitting data
#Since according to dataset's description, target values are highly imbalanced, so we split it in a stratified fashion.

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1,stratify = y)



# getting the counts

print("shape of x_train: ", x_train.shape)
print("shape of x_test: ", x_test.shape)
print("shape of y_train: ", y_train.shape)
print("shape of y_test: ", y_test.shape)
# Out:
# shape of x_train:  (1096, 590)
# shape of x_test:  (471, 590)
# shape of y_train:  (1096, 1)
# shape of y_test:  (471, 1)

# %%
#REMOVING FEATURES HAVING MISSING VALUE RATIO MORE THAN 50%.

def percentna(dataframe, threshold):
    columns = dataframe.columns[(dataframe.isnull().sum()/len(dataframe))>threshold]
    return columns.tolist()
na_columns = percentna(x_train, 0.5)
len(na_columns)
x_train_dn = x_train.drop(na_columns, axis=1)
x_train_dn.shape
# Out:
# (1096, 566)

# %%
#REMOVING COLUMNS WITH UNIQUE VALUES(Low Variance)

from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(x_train_dn)
constant_columns = [column for column in x_train_dn.columns
                    if column not in x_train_dn.columns[var_thres.get_support()]]
print(len(constant_columns))
x_train_lv = x_train_dn.drop(constant_columns,axis=1)
# Out:
# 116

# %%
#Dropping the Columns in test dataset also .
#In order to match the shape of x_train and x_test for further analysis.

x_test_drop = x_test.copy()
x_test_drop = x_test_drop.drop(na_columns, axis=1)
x_test_drop = x_test_drop.drop(constant_columns,axis=1)

# %% [markdown]
# # Step4:Outlier Treatment

# %%
#OUTLIER IMPUTATION using 3s rule

def outliers(feat):
 upper_limit = feat.mean() + 3*feat.std()
 lower_limit = feat.mean() - 3*feat.std()

 feat = np.where(
    feat >upper_limit,
    upper_limit,
    np.where(
       feat <lower_limit,
        lower_limit,
        feat ))
 return feat

x_train_outliers_imputation =x_train_lv.copy()
for column in x_train_outliers_imputation:
  x_train_outliers_imputation[column] = outliers(x_train_outliers_imputation[column])

# %% [markdown]
# # Step5: Missing value imputation

# %% [markdown]
# ##### Applying Gridsearch to find optimal parameter for Missing value imputaion using KNN Imputer

# %%
from sklearn.model_selection import GridSearchCV 
model_params = {
    'KNN': {
        'model': KNNImputer(),
        'params' : {
            'n_neighbors': list(range(1,30)),
            'weights' : ['uniform', 'distance'],
            'add_indicator': [True, False]
        }  
    }
}


scores = []
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'] ,scoring="accuracy",cv=None ,return_train_score=False)
    clf.fit(x_train_outliers_imputation, y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_,
        'best_estimator':clf.best_estimator_,
    })
    
gridsearch = pd.DataFrame(scores,columns=['model','best_score','best_params','best_estimator'])
gridsearch
# Out:
#   model  best_score                                        best_params  \
# 0   KNN         NaN  {'add_indicator': True, 'n_neighbors': 1, 'wei...
#
#                                   best_estimator
# 0  KNNImputer(add_indicator=True, n_neighbors=1)

# %%
#Using KNN Imputation Method

numColumns = x_train_outliers_imputation.select_dtypes(include=np.number).columns.tolist();
# initialize imputer
imputer = KNNImputer(n_neighbors = 1,weights='uniform')
# fit the imputer on X_train. pass only numeric columns.
imputer.fit(x_train_outliers_imputation[numColumns])
# transform the data using the fitted imputer
X_train_knn_impute1 = imputer.transform(x_train_outliers_imputation[numColumns])
X_test_knn_impute1 = imputer.transform(x_test[numColumns])
# put the output into DataFrame. remember to pass columns used in fit/transform
X_train_knn_impute1 = pd.DataFrame(X_train_knn_impute1, columns=numColumns)
X_test_knn_impute1 = pd.DataFrame(X_test_knn_impute1, columns=numColumns)

# %% [markdown]
# # Step6: Feature Selection

# %%
# !pip install boruta
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(random_state=1, n_estimators=1000, max_depth=5)
boruta_selector = BorutaPy(rfc, n_estimators='auto', verbose=2, random_state=1)
boruta_selector.fit(np.array(X_train_knn_impute1), np.array(y_train)) 

# Ranking of Boruta

print("Ranking: ",boruta_selector.ranking_)          
print("No. of significant features: ", boruta_selector.n_features_) 

selected_rf_features = pd.DataFrame({'Feature':list(X_train_knn_impute1.columns),
                                       'Ranking':boruta_selector.ranking_})
selected_rf_features.sort_values(by='Ranking').head(30)

# Using the BorutaPy object to transform the features in the dataset.

accepted = X_train_knn_impute1.columns[boruta_selector.support_].to_list()

undecided = X_train_knn_impute1.columns[boruta_selector.support_weak_].to_list()

selected_features = accepted + undecided

X_Filtered_train = X_train_knn_impute1[selected_features]
X_Filtered_test =  X_test_knn_impute1[selected_features]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 3.6 MB/s
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from boruta) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from boruta) (1.0.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from boruta) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.17.1->boruta) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.17.1->boruta) (3.1.0)
# Installing collected packages: boruta
# Successfully installed boruta-0.3
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	435
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	435
# Iteration: 	10 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	435
# Iteration: 	11 / 100
# Confirmed: 	0
# Tentative: 	15
# Rejected: 	435
# Iteration: 	12 / 100
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	435
# Iteration: 	13 / 100
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	435
# Iteration: 	14 / 100
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	435
# Iteration: 	15 / 100
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	435
# Iteration: 	16 / 100
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	435
# Iteration: 	17 / 100
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	435
# Iteration: 	18 / 100
# Confirmed: 	3
# Tentative: 	12
# Rejected: 	435
# Iteration: 	19 / 100
# Confirmed: 	5
# Tentative: 	10
# Rejected: 	435
# Iteration: 	20 / 100
# Confirmed: 	5
# Tentative: 	10
# Rejected: 	435
# Iteration: 	21 / 100
# Confirmed: 	5
# Tentative: 	10
# Rejected: 	435
# Iteration: 	22 / 100
# Confirmed: 	5
# Tentative: 	10
# Rejected: 	435
# Iteration: 	23 / 100
# Confirmed: 	5
# Tentative: 	10
# Rejected: 	435
# Iteration: 	24 / 100
# Confirmed: 	5
# Tentative: 	10
# Rejected: 	435
# Iteration: 	25 / 100
# Confirmed: 	5
# Tentative: 	10
# Rejected: 	435
# Iteration: 	26 / 100
# Confirmed: 	6
# Tentative: 	8
# Rejected: 	436
# Iteration: 	27 / 100
# Confirmed: 	6
# Tentative: 	8
# Rejected: 	436
# Iteration: 	28 / 100
# Confirmed: 	6
# Tentative: 	8
# Rejected: 	436
# Iteration: 	29 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	30 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	31 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	32 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	33 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	34 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	35 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	36 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	37 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	38 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	39 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	40 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	41 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	42 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	43 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	44 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	45 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	46 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	47 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	48 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	49 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	50 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	51 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	52 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	53 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	54 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	55 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	56 / 100
# Confirmed: 	8
# Tentative: 	6
# Rejected: 	436
# Iteration: 	57 / 100
# Confirmed: 	9
# Tentative: 	5
# Rejected: 	436
# Iteration: 	58 / 100
# Confirmed: 	9
# Tentative: 	5
# Rejected: 	436
# Iteration: 	59 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	436
# Iteration: 	60 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	436
# Iteration: 	61 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	436
# Iteration: 	62 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	436
# Iteration: 	63 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	436
# Iteration: 	64 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	436
# Iteration: 	65 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	436
# Iteration: 	66 / 100
# Confirmed: 	10
# Tentative: 	4
# Rejected: 	436
# Iteration: 	67 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	68 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	69 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	70 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	71 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	72 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	73 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	74 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	75 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	76 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	77 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	78 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	79 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	80 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	81 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	82 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	83 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	84 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	85 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	86 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	87 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	88 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	89 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	90 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	91 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	92 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	93 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	94 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	95 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	96 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	97 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	98 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
# Iteration: 	99 / 100
# Confirmed: 	11
# Tentative: 	3
# Rejected: 	436
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	11
# Tentative: 	2
# Rejected: 	436
# Ranking:  [ 95 408 135 353 317 391 383 353  87 137  80 163  92 333  11 268 288 381
#  285   6 123 394 367  64  20  18 324 301 152 298 209 123 342 257 311 179
#   10 265 184 119 213 240 116 349 131 237 293  39 393 271  41 267 182 294
#    1 305  25  54  12   1   1 324  81 148  98   4 195 241 437 134  83  94
#  256 317 177 108 247  91 308 404 356 236  96 172 389 200 205 423 365 418
#  423  71 238 429 115  46  89 336 192 338 274 228 241 122 249 380  14 330
#   87 129  30 158  43  42 320 163 272 270 302 417 314  32 186 330 397 362
#  221 282 382 245 308 397 363 336 189 150  79 194 287  44   1  67 338  23
#   45 170 377 367  62  23  69 400 254 113 103  34 198 286 275 414 358 358
#  404 356 409 297 263 235 166 247  57 111 193 132 209 149  70 153 175  21
#  223   6 437 185 163 437  35 154 138 252  30 227 121 228 219 321 292  73
#  295 379 170 224 141 232 159 118  48  37 191 129 314 369 396 352   1 200
#  182 420 400 199 375 391 307 322 425 157 344 252 196 147 161 344  50   3
#   85 212  85  26 188 374 415   8  15  77 348 336  30 167 165 135 409 279
#  403 303 110 369 197 279 326 306 252 154 234  35  52  68 222 178  75  99
#  106 219  56 226   2 434 203  92 421 261 437   1 142 113 384  39 276 145
#  289 189 416 347 174 231 266 139 334 224 389 314 261 310 243 111  58 120
#  159 299 411 332 277  16 100 351 413 203 101 323 342 246 377 289 328 258
#  418 125  89 105 303  76   1 143 186   9  17  39 412 258  51  28  97 216
#  346 263 179   1 156 330 168 384 399 387 422 281 366 372 261 172 151 250
#   60 109 202 144 360 207  72 387 211   1 132   2 437 230 295 340 407 355
#  255 426 371 218 311 168 269 239  58 215 175 216 373 117  13 128 103  61
#  431 326 140 273 402 291 317   1 233 209 428 433 432 430 284 349 364 395
#   21  27 406   5  32 146  49  19 206 299 243 181   1 427  85  77  73  55
#   66 127 319 282 360  53 377 101 386  47  64 107  64 126 278  81 214 342]
# No. of significant features:  11

# %% [markdown]
# #### Checking the results Using classifier before hyperparameter tuning & handling imbalance

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
#from sklearn.metrics import scorer
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import GridSearchCV 
from sklearn.model_selection import RandomizedSearchCV

classifiers = [['Naive Bayes :', GaussianNB()],
               ['KNeighbours :', KNeighborsClassifier()],
               ['SVM :', SVC()],
               ['LogisticRegression :', LogisticRegression()],
               ['DecisionTree :',DecisionTreeClassifier()],
               ['RandomForest :',RandomForestClassifier()]]

for name,classifier in classifiers:
    clf=classifier.fit(X_Filtered_train,y_train)
    y_pred=classifier.predict(X_Filtered_test)
    print(f'\n {name} \n')
    print(f'Training Score for {name}  {clf.score(X_Filtered_train,y_train) * 100:.2f}' )
    print(f'Testing Score for {name} {clf.score(X_Filtered_test,y_test) * 100:.2f}' )
    print(f'Classification report  \n {classification_report(y_test,y_pred)}' )
    print(f'Confusion matrix  \n {confusion_matrix(y_test,y_pred)}' )
    print(f'ROC AUC  : {roc_auc_score(y_test,y_pred)}' )
# Out:
#  Naive Bayes :
#
# Training Score for Naive Bayes :  90.24
# Testing Score for Naive Bayes : 89.17
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.95      0.93      0.94       440
#            1       0.24      0.29      0.26        31
#
#     accuracy                           0.89       471
#    macro avg       0.59      0.61      0.60       471
# weighted avg       0.90      0.89      0.90       471
#
# Confusion matrix
#  [[411  29]
#  [ 22   9]]
# ROC AUC  : 0.6122067448680352
#
#  KNeighbours :
#
# Training Score for KNeighbours :  93.34
# Testing Score for KNeighbours : 92.78
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.94      0.99      0.96       440
#            1       0.20      0.03      0.06        31
#
#     accuracy                           0.93       471
#    macro avg       0.57      0.51      0.51       471
# weighted avg       0.89      0.93      0.90       471
#
# Confusion matrix
#  [[436   4]
#  [ 30   1]]
# ROC AUC  : 0.51158357771261
#
#  SVM :
#
# Training Score for SVM :  93.34
# Testing Score for SVM : 93.42
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.93      1.00      0.97       440
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.93       471
#    macro avg       0.47      0.50      0.48       471
# weighted avg       0.87      0.93      0.90       471
#
# Confusion matrix
#  [[440   0]
#  [ 31   0]]
# ROC AUC  : 0.5
#
#  LogisticRegression :
#
# Training Score for LogisticRegression :  93.34
# Testing Score for LogisticRegression : 93.21
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.93      1.00      0.96       440
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.93       471
#    macro avg       0.47      0.50      0.48       471
# weighted avg       0.87      0.93      0.90       471
#
# Confusion matrix
#  [[439   1]
#  [ 31   0]]
# ROC AUC  : 0.49886363636363634
#
#  DecisionTree :
#
# Training Score for DecisionTree :  100.00
# Testing Score for DecisionTree : 89.60
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.95      0.93      0.94       440
#            1       0.28      0.35      0.31        31
#
#     accuracy                           0.90       471
#    macro avg       0.61      0.64      0.63       471
# weighted avg       0.91      0.90      0.90       471
#
# Confusion matrix
#  [[411  29]
#  [ 20  11]]
# ROC AUC  : 0.6444648093841643
#
#  RandomForest :
#
# Training Score for RandomForest :  100.00
# Testing Score for RandomForest : 93.21
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.94      1.00      0.96       440
#            1       0.33      0.03      0.06        31
#
#     accuracy                           0.93       471
#    macro avg       0.63      0.51      0.51       471
# weighted avg       0.90      0.93      0.91       471
#
# Confusion matrix
#  [[438   2]
#  [ 30   1]]
# ROC AUC  : 0.5138563049853373

# %% [markdown]
# #### find best model among all the classification algorithm using GridSearchCV

# %%
from sklearn import svm
model_params = {
   'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [10,20],
            'gamma': [1.0],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [69,60],
            'criterion' : ['entropy'],
            'max_depth': [24],
            'min_samples_split': [3],
            'max_samples' : [98]
        }
    },
     
    'Naive Bayes' : {
            'model': GaussianNB(),
            'params' : {
                'var_smoothing': np.logspace(0,-9, num=10000)}
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto',max_iter=600),
        'params': {
           'C': [2,3],
           'penalty':["l2"]
        }
    }
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=2, return_train_score=False)
    clf.fit(X_Filtered_train,y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df1 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df1
# Out:
#                  model  best_score  \
# 0                  svm    0.933394
# 1        random_forest    0.933394
# 2          Naive Bayes    0.930657
# 3  logistic_regression    0.932482
#
#                                          best_params
# 0           {'C': 10, 'gamma': 1.0, 'kernel': 'rbf'}
# 1  {'criterion': 'entropy', 'max_depth': 24, 'max...
# 2                             {'var_smoothing': 1.0}
# 3                          {'C': 2, 'penalty': 'l2'}

# %% [markdown]
# ##### The above the Best score and Best Parameters as stated by Grid search for Unbalanced dataset . We will balance the data and check the optimum balance method and best model for secom in the next steps

# %% [markdown]
# # Step7: Handling Imbalance

# %% [markdown]
# ##### Applying Gridsearch to find optimal parameter for Imbalance Methods

# %%
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import RandomOverSampler
model_params = {
    'SMOTE': {
        'model': SMOTE(),
        'params' : {
            'k_neighbors': list(range(1,30)),
            'random_state': [20,42,44]
        }  
    },
    'ROSE': {
        'model': RandomOverSampler(),
        'params' : {
            
            'random_state': [20,42,44]
        }  
    },
    'ADAYSN': {
        'model': ADASYN(),
        'params' : {
            'n_neighbors': list(range(1,30)),
            'random_state': [20,41,40,44]
        }  
    }
}



scores = []
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'] ,scoring="accuracy",cv=None ,return_train_score=False)
    clf.fit(X_train_knn_impute1, y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_,
        'best_estimator':clf.best_estimator_,
    })
    
gridsearch_SM = pd.DataFrame(scores,columns=['model','best_params','best_estimator'])
gridsearch_SM
# Out:
#     model                             best_params  \
# 0   SMOTE  {'k_neighbors': 1, 'random_state': 20}
# 1    ROSE                    {'random_state': 20}
# 2  ADAYSN  {'n_neighbors': 1, 'random_state': 20}
#
#                            best_estimator
# 0   SMOTE(k_neighbors=1, random_state=20)
# 1      RandomOverSampler(random_state=20)
# 2  ADASYN(n_neighbors=1, random_state=20)

# %% [markdown]
# ### Balancing Method: SMOTE

# %%
#pip install imblearn
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE

# %%
y_test.value_counts(normalize=True)
# Out:
# Result
# -1        0.934183
#  1        0.065817
# dtype: float64

# %%
y_train.value_counts(normalize=True)
# Out:
# Result
# -1        0.933394
#  1        0.066606
# dtype: float64

# %%
oversmote = SMOTE(k_neighbors=1, random_state=20)
X_train_sm, y_train_sm= oversmote.fit_resample(X_Filtered_train, y_train)

# %% [markdown]
# ##### Applying Gridsearch to find optimal parameter for Classifier algorithms

# %%
 model_params = {
       
    
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [10,20],
            'gamma': [1.0],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [69,60],
            'criterion' : ['entropy'],
            'max_depth': [24],
            'min_samples_split': [3],
            'max_samples' : [98]
        }
    },
     
    'Naive Bayes' : {
            'model': GaussianNB(),
            'params' : {
                'var_smoothing': np.logspace(0,-9, num=10000)}
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto',max_iter=600),
        'params': {
           'C': [2,3],
           'penalty':["l2"]
        }
    }
}
    
    
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=2, return_train_score=False)
    clf.fit(X_train_sm,y_train_sm)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,    
        'best_params': clf.best_params_,
        'best_estimator':clf.best_estimator_,
    })
    
df2 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df2
# Out:
#                  model  best_score  \
# 0                  svm    0.960899
# 1        random_forest    0.842620
# 2          Naive Bayes    0.686706
# 3  logistic_regression    0.692082
#
#                                          best_params
# 0           {'C': 10, 'gamma': 1.0, 'kernel': 'rbf'}
# 1  {'criterion': 'entropy', 'max_depth': 24, 'max...
# 2              {'var_smoothing': 0.9554281212853747}
# 3                          {'C': 3, 'penalty': 'l2'}

# %% [markdown]
# # Step8: Feature Scaling¶

# %%
col_name = list(X_Filtered_train.columns)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train_minmax = scaler.fit_transform(X_train_sm)

X_test_minmax =scaler.transform(X_Filtered_test)

X_train_minmax = pd.DataFrame(X_train_minmax, columns=col_name)
X_test_minmax = pd.DataFrame(X_test_minmax, columns=col_name)

# %% [markdown]
# ##### Classifiers which donot requires Feature scaling

# %%
#Algorithm

classifiers = [['Naive Bayes :', GaussianNB(var_smoothing = 0.688626606230121)],
                ['RandomForest :',RandomForestClassifier(n_estimators=69,criterion='entropy',max_depth=24,min_samples_split=3,max_samples=98)]]

for name,classifier in classifiers:
    clf=classifier.fit(X_train_sm,y_train_sm)
    y_pred=classifier.predict(X_Filtered_test)
    print(f'\n {name} \n')
    print(f'Training Score for {name}  {clf.score(X_train_sm,y_train_sm) * 100:.2f}' )
    print(f'Testing Score for {name} {clf.score(X_Filtered_test,y_test) * 100:.2f}' )
    print(f'Classification report  \n {classification_report(y_test,y_pred)}' )
    print(f'Confusion matrix  \n {confusion_matrix(y_test,y_pred)}' )
    print(f'ROC AUC  : {roc_auc_score(y_test,y_pred)}' )
    tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
    print('sensitivity is %f',1.*tp/(tp+fn))
    print('specificity is %f',1.*tn/(tn+fp))
    print('accuracy is %f',1.*(tp+tn)/(tp+tn+fp+fn))
    print('balanced accuracy is %',1./2*(1.*tp/(tp+fn)+1.*tn/(tn+fp)))
    print('Type1 Error is %f',1.*(fp))
    print('Type2 Error is %f',1.*(fn))
# Out:
#  Naive Bayes :
#
# Training Score for Naive Bayes :  68.57
# Testing Score for Naive Bayes : 84.50
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.96      0.87      0.91       440
#            1       0.22      0.52      0.30        31
#
#     accuracy                           0.85       471
#    macro avg       0.59      0.69      0.61       471
# weighted avg       0.91      0.85      0.87       471
#
# Confusion matrix
#  [[382  58]
#  [ 15  16]]
# ROC AUC  : 0.6921554252199413
# sensitivity is %f 0.5161290322580645
# specificity is %f 0.8681818181818182
# accuracy is %f 0.8450106157112527
# balanced accuracy is % 0.6921554252199413
# Type1 Error is %f 58.0
# Type2 Error is %f 15.0
#
#  RandomForest :
#
# Training Score for RandomForest :  88.07
# Testing Score for RandomForest : 77.92
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.95      0.80      0.87       440
#            1       0.14      0.45      0.21        31
#
#     accuracy                           0.78       471
#    macro avg       0.55      0.63      0.54       471
# weighted avg       0.90      0.78      0.83       471
#
# Confusion matrix
#  [[353  87]
#  [ 17  14]]
# ROC AUC  : 0.6269428152492669
# sensitivity is %f 0.45161290322580644
# specificity is %f 0.8022727272727272
# accuracy is %f 0.7791932059447984
# balanced accuracy is % 0.6269428152492669
# Type1 Error is %f 87.0
# Type2 Error is %f 17.0

# %% [markdown]
# ##### Classifiers which requires Feature scaling

# %%
classifiers = [['SVM :', SVC(C=10.0, gamma=1.0, kernel='linear')],
               ['LogisticRegression :', LogisticRegression(penalty='l2',C=2,solver='liblinear',max_iter=600)]]

for name,classifier in classifiers:
    clf=classifier.fit(X_train_minmax,y_train_sm)
    y_pred=classifier.predict(X_test_minmax)
    print(f'\n {name} \n')
    print(f'Training Score for {name}  {clf.score(X_train_minmax,y_train_sm) * 100:.2f}' )
    print(f'Testing Score for {name} {clf.score(X_test_minmax,y_test) * 100:.2f}' )
    print(f'Classification report  \n {classification_report(y_test,y_pred)}' )
    print(f'Confusion matrix  \n {confusion_matrix(y_test,y_pred)}' )
    print(f'ROC AUC  : {roc_auc_score(y_test,y_pred)}' )
    tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
    print('sensitivity is %f',1.*tp/(tp+fn))
    print('specificity is %f',1.*tn/(tn+fp))
    print('accuracy is %f',1.*(tp+tn)/(tp+tn+fp+fn))
    print('balanced accuracy is %',1./2*(1.*tp/(tp+fn)+1.*tn/(tn+fp)))
    print('Type1 Error is %f',1.*(fp))
    print('Type2 Error is %f',1.*(fn))
# Out:
#  SVM :
#
# Training Score for SVM :  67.60
# Testing Score for SVM : 85.14
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.96      0.88      0.92       440
#            1       0.23      0.52      0.31        31
#
#     accuracy                           0.85       471
#    macro avg       0.59      0.70      0.62       471
# weighted avg       0.91      0.85      0.88       471
#
# Confusion matrix
#  [[385  55]
#  [ 15  16]]
# ROC AUC  : 0.6955645161290323
# sensitivity is %f 0.5161290322580645
# specificity is %f 0.875
# accuracy is %f 0.851380042462845
# balanced accuracy is % 0.6955645161290323
# Type1 Error is %f 55.0
# Type2 Error is %f 15.0
#
#  LogisticRegression :
#
# Training Score for LogisticRegression :  69.11
# Testing Score for LogisticRegression : 81.53
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.96      0.83      0.89       440
#            1       0.19      0.55      0.28        31
#
#     accuracy                           0.82       471
#    macro avg       0.58      0.69      0.59       471
# weighted avg       0.91      0.82      0.85       471
#
# Confusion matrix
#  [[367  73]
#  [ 14  17]]
# ROC AUC  : 0.6912390029325514
# sensitivity is %f 0.5483870967741935
# specificity is %f 0.8340909090909091
# accuracy is %f 0.8152866242038217
# balanced accuracy is % 0.6912390029325512
# Type1 Error is %f 73.0
# Type2 Error is %f 14.0

# %% [markdown]
# ### Balancing Method: ROSE

# %%
rose = RandomOverSampler(random_state=20)
X_train_rs, y_train_rs= rose.fit_resample(X_Filtered_train, y_train)

# %%
# Feature scaling after ROSE

scaler = MinMaxScaler()

X_train_minmax_rs = scaler.fit_transform(X_train_rs)

X_test_minmax_rs =scaler.transform(X_Filtered_test)

X_train_minmax_rs = pd.DataFrame(X_train_minmax_rs, columns=col_name)
X_test_minmax_rs = pd.DataFrame(X_test_minmax_rs, columns=col_name)

# %%
 model_params = {
       
    
     'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [10,20],
            'gamma': [1.0],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [69,60],
            'criterion' : ['entropy'],
            'max_depth': [24],
            'min_samples_split': [3],
            'max_samples' : [98]
        }
    },
     
    'Naive Bayes' : {
            'model': GaussianNB(),
            'params' : {
                'var_smoothing': np.logspace(0,-9, num=10000)}
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto',max_iter=600),
        'params': {
           'C': [2,3],
           'penalty':["l2"]
        }
    }
}
    
    
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=2, return_train_score=False)
    clf.fit(X_train_rs,y_train_rs)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,    
        'best_params': clf.best_params_,
        'best_estimator':clf.best_estimator_,
    })
    
df3 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df3
# Out:
#                  model  best_score  \
# 0                  svm    1.000000
# 1        random_forest    0.878788
# 2          Naive Bayes    0.691105
# 3  logistic_regression    0.695015
#
#                                          best_params
# 0           {'C': 10, 'gamma': 1.0, 'kernel': 'rbf'}
# 1  {'criterion': 'entropy', 'max_depth': 24, 'max...
# 2          {'var_smoothing': 2.9932818669066775e-08}
# 3                          {'C': 2, 'penalty': 'l2'}

# %% [markdown]
# ##### Classifiers which donot requires Feature scaling

# %%
#Algorithm

classifiers = [['Naive Bayes :', GaussianNB(var_smoothing = 0.688626606230121)],
               ['RandomForest :',RandomForestClassifier(n_estimators=69,criterion='entropy',max_depth=24,min_samples_split=3,max_samples=98)]]

for name,classifier in classifiers:
    clf=classifier.fit(X_train_rs,y_train_rs)
    y_pred=classifier.predict(X_Filtered_test)
    print(f'\n {name} \n')
    print(f'Training Score for {name}  {clf.score(X_train_rs,y_train_rs) * 100:.2f}' )
    print(f'Testing Score for {name} {clf.score(X_Filtered_test,y_test) * 100:.2f}' )
    print(f'Classification report  \n {classification_report(y_test,y_pred)}' )
    print(f'Confusion matrix  \n {confusion_matrix(y_test,y_pred)}' )
    print(f'ROC AUC  : {roc_auc_score(y_test,y_pred)}' )
    tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
    print('sensitivity is %f',1.*tp/(tp+fn))
    print('specificity is %f',1.*tn/(tn+fp))
    print('accuracy is %f',1.*(tp+tn)/(tp+tn+fp+fn))
    print('balanced accuracy is %',1./2*(1.*tp/(tp+fn)+1.*tn/(tn+fp)))
    print('Type1 Error is %f',1.*(fp))
    print('Type2 Error is %f',1.*(fn))
# Out:
#  Naive Bayes :
#
# Training Score for Naive Bayes :  66.81
# Testing Score for Naive Bayes : 85.35
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.96      0.88      0.92       440
#            1       0.22      0.48      0.30        31
#
#     accuracy                           0.85       471
#    macro avg       0.59      0.68      0.61       471
# weighted avg       0.91      0.85      0.88       471
#
# Confusion matrix
#  [[387  53]
#  [ 16  15]]
# ROC AUC  : 0.6817082111436951
# sensitivity is %f 0.4838709677419355
# specificity is %f 0.8795454545454545
# accuracy is %f 0.8535031847133758
# balanced accuracy is % 0.681708211143695
# Type1 Error is %f 53.0
# Type2 Error is %f 16.0
#
#  RandomForest :
#
# Training Score for RandomForest :  91.40
# Testing Score for RandomForest : 77.71
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.97      0.79      0.87       440
#            1       0.17      0.61      0.27        31
#
#     accuracy                           0.78       471
#    macro avg       0.57      0.70      0.57       471
# weighted avg       0.91      0.78      0.83       471
#
# Confusion matrix
#  [[347  93]
#  [ 12  19]]
# ROC AUC  : 0.7007697947214075
# sensitivity is %f 0.6129032258064516
# specificity is %f 0.7886363636363637
# accuracy is %f 0.7770700636942676
# balanced accuracy is % 0.7007697947214077
# Type1 Error is %f 93.0
# Type2 Error is %f 12.0

# %% [markdown]
# ##### Classifiers which requires Feature scaling

# %%
classifiers = [['SVM :', SVC(C=10.0, gamma=1.0, kernel='linear')],
               ['LogisticRegression :', LogisticRegression(penalty='l2',C=2,solver='liblinear',max_iter=600)]]

for name,classifier in classifiers:
    clf=classifier.fit(X_train_minmax_rs ,y_train_rs)
    y_pred=classifier.predict(X_test_minmax_rs)
    print(f'\n {name} \n')
    print(f'Training Score for {name}  {clf.score(X_train_minmax_rs,y_train_rs) * 100:.2f}' )
    print(f'Testing Score for {name} {clf.score(X_test_minmax_rs,y_test) * 100:.2f}' )
    print(f'Classification report  \n {classification_report(y_test,y_pred)}' )
    print(f'Confusion matrix  \n {confusion_matrix(y_test,y_pred)}' )
    print(f'ROC AUC  : {roc_auc_score(y_test,y_pred)}' )
    tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
    print('sensitivity is %f',1.*tp/(tp+fn))
    print('specificity is %f',1.*tn/(tn+fp))
    print('accuracy is %f',1.*(tp+tn)/(tp+tn+fp+fn))
    print('balanced accuracy is %',1./2*(1.*tp/(tp+fn)+1.*tn/(tn+fp)))
    print('Type1 Error is %f',1.*(fp))
    print('Type2 Error is %f',1.*(fn))
# Out:
#  SVM :
#
# Training Score for SVM :  67.60
# Testing Score for SVM : 85.35
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.96      0.88      0.92       440
#            1       0.23      0.52      0.32        31
#
#     accuracy                           0.85       471
#    macro avg       0.60      0.70      0.62       471
# weighted avg       0.91      0.85      0.88       471
#
# Confusion matrix
#  [[386  54]
#  [ 15  16]]
# ROC AUC  : 0.6967008797653959
# sensitivity is %f 0.5161290322580645
# specificity is %f 0.8772727272727273
# accuracy is %f 0.8535031847133758
# balanced accuracy is % 0.696700879765396
# Type1 Error is %f 54.0
# Type2 Error is %f 15.0
#
#  LogisticRegression :
#
# Training Score for LogisticRegression :  69.31
# Testing Score for LogisticRegression : 81.74
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.96      0.84      0.90       440
#            1       0.19      0.55      0.28        31
#
#     accuracy                           0.82       471
#    macro avg       0.58      0.69      0.59       471
# weighted avg       0.91      0.82      0.86       471
#
# Confusion matrix
#  [[368  72]
#  [ 14  17]]
# ROC AUC  : 0.692375366568915
# sensitivity is %f 0.5483870967741935
# specificity is %f 0.8363636363636363
# accuracy is %f 0.8174097664543525
# balanced accuracy is % 0.692375366568915
# Type1 Error is %f 72.0
# Type2 Error is %f 14.0

# %% [markdown]
# ### Balancing Method: ADASYN

# %%
adasyn = ADASYN(n_neighbors=1, random_state=20)
X_train_ad, y_train_ad= adasyn.fit_resample(X_Filtered_train, y_train)

# %%
# Feature scaling after ADASYN

scaler = MinMaxScaler()

X_train_minmax_ad = scaler.fit_transform(X_train_ad)

X_test_minmax_ad =scaler.transform(X_Filtered_test)

X_train_minmax_ad = pd.DataFrame(X_train_minmax_ad, columns=col_name)
X_test_minmax_ad = pd.DataFrame(X_test_minmax_ad, columns=col_name)

# %%
 model_params = {
       
    
    'svm': {
        'model': svm.SVC(),
        'params' : {
            'C': [10,20],
            'gamma': [1.0],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [69,60],
            'criterion' : ['entropy'],
            'max_depth': [24],
            'min_samples_split': [3],
            'max_samples' : [98]
        }
    },
     
    'Naive Bayes' : {
            'model': GaussianNB(),
            'params' : {
                'var_smoothing': np.logspace(0,-9, num=10000)}
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto',max_iter=600),
        'params': {
           'C': [2,3],
           'penalty':["l2"]
        }
    }
}
    
    
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=2, return_train_score=False)
    clf.fit(X_train_ad,y_train_ad)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,    
        'best_params': clf.best_params_,
        'best_estimator':clf.best_estimator_,
    })
    
df4 = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df4
# Out:
#                  model  best_score  \
# 0                  svm    0.763893
# 1        random_forest    0.770171
# 2          Naive Bayes    0.667332
# 3  logistic_regression    0.667810
#
#                                          best_params
# 0           {'C': 10, 'gamma': 1.0, 'kernel': 'rbf'}
# 1  {'criterion': 'entropy', 'max_depth': 24, 'max...
# 2               {'var_smoothing': 0.688626606230121}
# 3                          {'C': 2, 'penalty': 'l2'}

# %% [markdown]
# ###### Classifiers which donot requires Feature scaling

# %%
#Algorithm

classifiers = [['Naive Bayes :', GaussianNB(var_smoothing = 0.688626606230121)],
               ['RandomForest :',RandomForestClassifier(n_estimators=69,criterion='entropy',max_depth=24,min_samples_split=3,max_samples=98)]]

for name,classifier in classifiers:
    clf=classifier.fit(X_train_ad,y_train_ad)
    y_pred=classifier.predict(X_Filtered_test)
    print(f'\n {name} \n')
    print(f'Training Score for {name}  {clf.score(X_train_ad,y_train_ad) * 100:.2f}' )
    print(f'Testing Score for {name} {clf.score(X_Filtered_test,y_test) * 100:.2f}' )
    print(f'Classification report  \n {classification_report(y_test,y_pred)}' )
    print(f'Confusion matrix  \n {confusion_matrix(y_test,y_pred)}' )
    print(f'ROC AUC  : {roc_auc_score(y_test,y_pred)}' )
    tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
    print('sensitivity is %f',1.*tp/(tp+fn))
    print('specificity is %f',1.*tn/(tn+fp))
    print('accuracy is %f',1.*(tp+tn)/(tp+tn+fp+fn))
    print('balanced accuracy is %',1./2*(1.*tp/(tp+fn)+1.*tn/(tn+fp)))
    print('Type1 Error is %f',1.*(fp))
    print('Type2 Error is %f',1.*(fn))
# Out:
#  Naive Bayes :
#
# Training Score for Naive Bayes :  66.73
# Testing Score for Naive Bayes : 84.71
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.96      0.87      0.91       440
#            1       0.22      0.52      0.31        31
#
#     accuracy                           0.85       471
#    macro avg       0.59      0.69      0.61       471
# weighted avg       0.91      0.85      0.87       471
#
# Confusion matrix
#  [[383  57]
#  [ 15  16]]
# ROC AUC  : 0.693291788856305
# sensitivity is %f 0.5161290322580645
# specificity is %f 0.8704545454545455
# accuracy is %f 0.8471337579617835
# balanced accuracy is % 0.693291788856305
# Type1 Error is %f 57.0
# Type2 Error is %f 15.0
#
#  RandomForest :
#
# Training Score for RandomForest :  88.03
# Testing Score for RandomForest : 77.49
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.95      0.80      0.87       440
#            1       0.12      0.39      0.18        31
#
#     accuracy                           0.77       471
#    macro avg       0.54      0.59      0.53       471
# weighted avg       0.89      0.77      0.82       471
#
# Confusion matrix
#  [[353  87]
#  [ 19  12]]
# ROC AUC  : 0.5946847507331379
# sensitivity is %f 0.3870967741935484
# specificity is %f 0.8022727272727272
# accuracy is %f 0.7749469214437368
# balanced accuracy is % 0.5946847507331379
# Type1 Error is %f 87.0
# Type2 Error is %f 19.0

# %% [markdown]
# ##### Classifiers which requires Feature scaling

# %%
classifiers = [['SVM :', SVC(C=10.0, gamma=1.0, kernel='linear')],
               ['LogisticRegression :', LogisticRegression(penalty='l2',C=2,solver='liblinear',max_iter=600)]]

for name,classifier in classifiers:
    clf=classifier.fit(X_train_minmax_ad,y_train_ad)
    y_pred=classifier.predict(X_test_minmax_ad)
    print(f'\n {name} \n')
    print(f'Training Score for {name}  {clf.score(X_train_minmax_ad,y_train_ad) * 100:.2f}' )
    print(f'Testing Score for {name} {clf.score(X_test_minmax_ad,y_test) * 100:.2f}' )
    print(f'Classification report  \n {classification_report(y_test,y_pred)}' )
    print(f'Confusion matrix  \n {confusion_matrix(y_test,y_pred)}' )
    print(f'ROC AUC  : {roc_auc_score(y_test,y_pred)}' )
    tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
    print('sensitivity is %f',1.*tp/(tp+fn))
    print('specificity is %f',1.*tn/(tn+fp))
    print('accuracy is %f',1.*(tp+tn)/(tp+tn+fp+fn))
    print('balanced accuracy is %',1./2*(1.*tp/(tp+fn)+1.*tn/(tn+fp)))
    print('Type1 Error is %f',1.*(fp))
    print('Type2 Error is %f',1.*(fn))
# Out:
#  SVM :
#
# Training Score for SVM :  65.52
# Testing Score for SVM : 85.14
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.96      0.88      0.92       440
#            1       0.23      0.52      0.31        31
#
#     accuracy                           0.85       471
#    macro avg       0.59      0.70      0.62       471
# weighted avg       0.91      0.85      0.88       471
#
# Confusion matrix
#  [[385  55]
#  [ 15  16]]
# ROC AUC  : 0.6955645161290323
# sensitivity is %f 0.5161290322580645
# specificity is %f 0.875
# accuracy is %f 0.851380042462845
# balanced accuracy is % 0.6955645161290323
# Type1 Error is %f 55.0
# Type2 Error is %f 15.0
#
#  LogisticRegression :
#
# Training Score for LogisticRegression :  69.05
# Testing Score for LogisticRegression : 78.13
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.96      0.80      0.87       440
#            1       0.17      0.58      0.26        31
#
#     accuracy                           0.78       471
#    macro avg       0.57      0.69      0.57       471
# weighted avg       0.91      0.78      0.83       471
#
# Confusion matrix
#  [[350  90]
#  [ 13  18]]
# ROC AUC  : 0.688049853372434
# sensitivity is %f 0.5806451612903226
# specificity is %f 0.7954545454545454
# accuracy is %f 0.7813163481953291
# balanced accuracy is % 0.688049853372434
# Type1 Error is %f 90.0
# Type2 Error is %f 13.0

# %%
fig, ax = plt.subplots(2,2, figsize=(16, 8))
sns.barplot(x="best_score", y="model", data=df1.sort_values(by="best_score"), ax=ax[0,0])
ax[0,0].set_title("Unbalanced Test Acc")
sns.barplot(x="best_score", y="model", data=df2.sort_values(by="best_score"), ax=ax[0,1])
ax[0,1].set_title("Smote Test Acc")
sns.barplot(x="best_score", y="model", data=df3.sort_values(by="best_score"), ax=ax[1,0])
ax[1,0].set_title("ROSE Test Acc")
sns.barplot(x="best_score", y="model", data=df4.sort_values(by="best_score"), ax=ax[1,1])
ax[1,1].set_title("ADASYN Test Acc")



plt.tight_layout()
plt.show()

# %% [markdown]
# # Step9 :Model Assessment

# %% [markdown]
# ![image.png](attachment:8d42eea1-6466-46c0-b5a5-fe63c62db23c.png)

# %% [markdown]
# # Step9: Final Data Modelling

# %%
# defining the parameters for a pie chart

labels = "Naive Bayes","Random Forest", "SVM", "LogReg" 
size = [85.35, 77.71, 85.35, 81.74]
colors = ['pink',  'lightgreen', 'crimson','lightblue' ]

# Create a circle for the center of the plot
my_circle = plt.Circle( (0,0), 0.7, color = 'white')

plt.rcParams['figure.figsize'] = (10, 10)
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Greater Area Means Greater Role in  Accuracy')
p = plt.gcf()
p.gca().add_artist(my_circle)
#plt.legend()
plt.show()

# %% [markdown]
# # Step10: Model Evaluation

# %%
classifiers = [['SVM :', SVC(C=10.0, gamma=1.0, kernel='linear')]]

for name,classifier in classifiers:
    clf=classifier.fit(X_train_minmax_rs ,y_train_rs)
    y_pred=classifier.predict(X_test_minmax_rs)
    print(f'\n {name} \n')
    print(f'Training Score for {name}  {clf.score(X_train_minmax_rs,y_train_rs) * 100:.2f}' )
    print(f'Testing Score for {name} {clf.score(X_test_minmax_rs,y_test) * 100:.2f}' )
    print(f'Classification report  \n {classification_report(y_test,y_pred)}' )
    print(f'Confusion matrix  \n {confusion_matrix(y_test,y_pred)}' )
    print(f'ROC AUC  : {roc_auc_score(y_test,y_pred)}' )
    tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
    print('sensitivity is %f',1.*tp/(tp+fn))
    print('specificity is %f',1.*tn/(tn+fp))
    print('accuracy is %f',1.*(tp+tn)/(tp+tn+fp+fn))
    print('balanced accuracy is %',1./2*(1.*tp/(tp+fn)+1.*tn/(tn+fp)))
    print('Type1 Error is %f',1.*(fp))
    print('Type2 Error is %f',1.*(fn))
# Out:
#  SVM :
#
# Training Score for SVM :  67.60
# Testing Score for SVM : 85.35
# Classification report
#                precision    recall  f1-score   support
#
#           -1       0.96      0.88      0.92       440
#            1       0.23      0.52      0.32        31
#
#     accuracy                           0.85       471
#    macro avg       0.60      0.70      0.62       471
# weighted avg       0.91      0.85      0.88       471
#
# Confusion matrix
#  [[386  54]
#  [ 15  16]]
# ROC AUC  : 0.6967008797653959
# sensitivity is %f 0.5161290322580645
# specificity is %f 0.8772727272727273
# accuracy is %f 0.8535031847133758
# balanced accuracy is % 0.696700879765396
# Type1 Error is %f 54.0
# Type2 Error is %f 15.0
