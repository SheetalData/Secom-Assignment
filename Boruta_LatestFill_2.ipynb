# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from scipy.stats import shapiro
# imputer
from sklearn.impute import SimpleImputer, KNNImputer




url1 ='https://archive.ics.uci.edu/ml/machine-learning-databases/secom/secom.data'
names = ["feature" + str(x) for x in range(1, 591)]
df1 = pd.read_csv(url1,sep=" ", names=names, na_values = "NaN",header=None)
df1.head()

url2 ='https://archive.ics.uci.edu/ml/machine-learning-databases/secom/secom_labels.data'
df2 = pd.read_csv(url2,sep=" ",names = ["Result","Date"])

#df2.columns =['Pass/Fail','Date']
df2.head()




#Convertion of Date into Datetime from Object(String) data types
df2['Date'] = pd.to_datetime(df2['Date'])
df2.dtypes



#Joinig TWO df1 and df2 Dataframe naming SECOM
Secom = pd.concat([df1,df2],axis = 1)
print(Secom)

Secom = Secom.drop(['Date'],axis=1)
                   
# establish target and features of the manufacturing data
# set the target to the encoded manufacturing outcome column
y = Secom[['Result']]
# set the features as the rest of the dataset after dropping the features that are no
x = Secom.drop(['Result'], axis=1)

# getting the shapes of new data sets x and y
print("shape of x:", x.shape)
print("shape of y:", y.shape)

#Splitting data


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1,stratify = y)



# getting the counts
print("shape of x_train: ", x_train.shape)
print("shape of x_test: ", x_test.shape)
print("shape of y_train: ", y_train.shape)
print("shape of y_test: ", y_test.shape)




#Removing features having Missing ratio more than 50%


def percentna(dataframe, threshold):
    columns = dataframe.columns[(dataframe.isnull().sum()/len(dataframe))>threshold]
    return columns.tolist()

 

na_columns = percentna(x_train, 0.5)
len(na_columns)
x_train_dn = x_train.drop(na_columns, axis=1)
x_train_dn.shape





#Low Variance Filter
from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(x_train_dn)

 

constant_columns = [column for column in x_train_dn.columns
                    if column not in x_train_dn.columns[var_thres.get_support()]]


print(len(constant_columns))

x_train_lv = x_train_dn.drop(constant_columns,axis=1)
# Out:
#       feature1  feature2   feature3   feature4  feature5  feature6  feature7  \
# 0      3030.93   2564.00  2187.7333  1411.1265    1.3602     100.0   97.6133
# 1      3095.78   2465.14  2230.4222  1463.6606    0.8294     100.0  102.3433
# 2      2932.61   2559.94  2186.4111  1698.0172    1.5102     100.0   95.4878
# 3      2988.72   2479.90  2199.0333   909.7926    1.3204     100.0  104.2367
# 4      3032.24   2502.87  2233.3667  1326.5200    1.5334     100.0  100.3967
# ...        ...       ...        ...        ...       ...       ...       ...
# 1562   2899.41   2464.36  2179.7333  3085.3781    1.4843     100.0   82.2467
# 1563   3052.31   2522.55  2198.5667  1124.6595    0.8763     100.0   98.4689
# 1564   2978.81   2379.78  2206.3000  1110.4967    0.8236     100.0   99.4122
# 1565   2894.92   2532.01  2177.0333  1183.7287    1.5726     100.0   98.7978
# 1566   2944.92   2450.76  2195.4444  2914.1792    1.5978     100.0   85.1011
#
#       feature8  feature9  feature10  ...  feature583  feature584  feature585  \
# 0       0.1242    1.5005     0.0162  ...      0.5005      0.0118      0.0035
# 1       0.1247    1.4966    -0.0005  ...      0.5019      0.0223      0.0055
# 2       0.1241    1.4436     0.0041  ...      0.4958      0.0157      0.0039
# 3       0.1217    1.4882    -0.0124  ...      0.4990      0.0103      0.0025
# 4       0.1235    1.5031    -0.0031  ...      0.4800      0.4766      0.1045
# ...        ...       ...        ...  ...         ...         ...         ...
# 1562    0.1248    1.3424    -0.0045  ...      0.4988      0.0143      0.0039
# 1563    0.1205    1.4333    -0.0061  ...      0.4975      0.0131      0.0036
# 1564    0.1208       NaN        NaN  ...      0.4987      0.0153      0.0041
# 1565    0.1213    1.4622    -0.0072  ...      0.5004      0.0178      0.0038
# 1566    0.1235       NaN        NaN  ...      0.4987      0.0181      0.0040
#
#       feature586  feature587  feature588  feature589  feature590  Result  \
# 0         2.3630         NaN         NaN         NaN         NaN      -1
# 1         4.4447      0.0096      0.0201      0.0060    208.2045      -1
# 2         3.1745      0.0584      0.0484      0.0148     82.8602       1
# 3         2.0544      0.0202      0.0149      0.0044     73.8432      -1
# 4        99.3032      0.0202      0.0149      0.0044     73.8432      -1
# ...          ...         ...         ...         ...         ...     ...
# 1562      2.8669      0.0068      0.0138      0.0047    203.1720      -1
# 1563      2.6238      0.0068      0.0138      0.0047    203.1720      -1
# 1564      3.0590      0.0197      0.0086      0.0025     43.5231      -1
# 1565      3.5662      0.0262      0.0245      0.0075     93.4941      -1
# 1566      3.6275      0.0117      0.0162      0.0045    137.7844      -1
#
#                     Date
# 0    2008-07-19 11:55:00
# 1    2008-07-19 12:32:00
# 2    2008-07-19 13:17:00
# 3    2008-07-19 14:43:00
# 4    2008-07-19 15:22:00
# ...                  ...
# 1562 2008-10-16 15:13:00
# 1563 2008-10-16 20:49:00
# 1564 2008-10-17 05:26:00
# 1565 2008-10-17 06:01:00
# 1566 2008-10-17 06:07:00
#
# [1567 rows x 592 columns]
# shape of x: (1567, 590)
# shape of y: (1567, 1)
# shape of x_train:  (1096, 590)
# shape of x_test:  (471, 590)
# shape of y_train:  (1096, 1)
# shape of y_test:  (471, 1)
# 116

# %%
def IQR_outliers(data,limit=1.5):
    numColumns = data.select_dtypes(include=np.number).columns.tolist(); # extract list of numeric columns
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3-Q1;
    outliers=((data[numColumns] < (Q1 - limit*IQR)) | (data[numColumns] > (Q3 + limit*IQR))).sum()*100/data.shape[0]
    return outliers 
from sklearn.preprocessing import QuantileTransformer
x_train_lv = x_train_lv.copy()
quantile_transformer = QuantileTransformer(output_distribution='normal', random_state= 42)
df_outliers = pd.DataFrame(quantile_transformer.fit_transform(x_train_lv),columns=x_train_lv.columns)
outliers = IQR_outliers(df_outliers)

# %%
# latest information available
x_train_LastFill2 = df_outliers.copy()
x_train_LastFill2.fillna(method='bfill',inplace =True)
x_train_LastFill2.fillna(method='ffill', inplace=True)

x_train_LastFill2

x_train_LastFill2.isna().mean().sort_values(ascending=False).head(10)
# Out:
# feature1      0.0
# feature434    0.0
# feature391    0.0
# feature390    0.0
# feature389    0.0
# feature388    0.0
# feature387    0.0
# feature386    0.0
# feature378    0.0
# feature377    0.0
# dtype: float64

# %%
x_test_LastFill2 = x_test.copy()
#x_test_LastFill2.fillna(method='ffill', inplace=True)
x_test_LastFill2.fillna(method='bfill')
x_test_LastFill2

x_test_LastFill2.isna().sum().sort_values(ascending=False).head(10)
# Out:
# feature294    429
# feature158    429
# feature159    429
# feature293    429
# feature493    397
# feature86     397
# feature359    397
# feature221    397
# feature519    304
# feature517    304
# dtype: int64

# %%
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(random_state=1, n_estimators=1000, max_depth=5)
boruta_selector = BorutaPy(rfc, n_estimators='auto', verbose=2, random_state=1)
boruta_selector.fit(np.array(x_train_LastFill2), np.array(y_train)) 

# Ranking of Boruta

print("Ranking: ",boruta_selector.ranking_)          
print("No. of significant features: ", boruta_selector.n_features_) 

selected_rf_features = pd.DataFrame({'Feature':list(x_train_LastFill2.columns),
                                       'Ranking':boruta_selector.ranking_})
selected_rf_features.sort_values(by='Ranking').head(30)

# Using the BorutaPy object to transform the features in the dataset.

X_Filtered_train = boruta_selector.transform(np.array(x_train_LastFill2))

X_Filtered_test = boruta_selector.transform(np.array(x_test_LastFill2))
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	450
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	16
# Rejected: 	434
# Iteration: 	9 / 100
# Confirmed: 	1
# Tentative: 	15
# Rejected: 	434
# Iteration: 	10 / 100
# Confirmed: 	1
# Tentative: 	15
# Rejected: 	434
# Iteration: 	11 / 100
# Confirmed: 	1
# Tentative: 	15
# Rejected: 	434
# Iteration: 	12 / 100
# Confirmed: 	2
# Tentative: 	14
# Rejected: 	434
# Iteration: 	13 / 100
# Confirmed: 	2
# Tentative: 	14
# Rejected: 	434
# Iteration: 	14 / 100
# Confirmed: 	2
# Tentative: 	14
# Rejected: 	434
# Iteration: 	15 / 100
# Confirmed: 	2
# Tentative: 	14
# Rejected: 	434
# Iteration: 	16 / 100
# Confirmed: 	2
# Tentative: 	14
# Rejected: 	434
# Iteration: 	17 / 100
# Confirmed: 	2
# Tentative: 	14
# Rejected: 	434
# Iteration: 	18 / 100
# Confirmed: 	2
# Tentative: 	14
# Rejected: 	434
# Iteration: 	19 / 100
# Confirmed: 	2
# Tentative: 	14
# Rejected: 	434
# Iteration: 	20 / 100
# Confirmed: 	2
# Tentative: 	14
# Rejected: 	434
# Iteration: 	21 / 100
# Confirmed: 	2
# Tentative: 	14
# Rejected: 	434
# Iteration: 	22 / 100
# Confirmed: 	3
# Tentative: 	13
# Rejected: 	434
# Iteration: 	23 / 100
# Confirmed: 	3
# Tentative: 	13
# Rejected: 	434
# Iteration: 	24 / 100
# Confirmed: 	3
# Tentative: 	13
# Rejected: 	434
# Iteration: 	25 / 100
# Confirmed: 	3
# Tentative: 	13
# Rejected: 	434
# Iteration: 	26 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	434
# Iteration: 	27 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	434
# Iteration: 	28 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	434
# Iteration: 	29 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	434
# Iteration: 	30 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	434
# Iteration: 	31 / 100
# Confirmed: 	6
# Tentative: 	10
# Rejected: 	434
# Iteration: 	32 / 100
# Confirmed: 	7
# Tentative: 	9
# Rejected: 	434
# Iteration: 	33 / 100
# Confirmed: 	7
# Tentative: 	9
# Rejected: 	434
# Iteration: 	34 / 100
# Confirmed: 	9
# Tentative: 	7
# Rejected: 	434
# Iteration: 	35 / 100
# Confirmed: 	9
# Tentative: 	7
# Rejected: 	434
# Iteration: 	36 / 100
# Confirmed: 	9
# Tentative: 	7
# Rejected: 	434
# Iteration: 	37 / 100
# Confirmed: 	9
# Tentative: 	7
# Rejected: 	434
# Iteration: 	38 / 100
# Confirmed: 	9
# Tentative: 	7
# Rejected: 	434
# Iteration: 	39 / 100
# Confirmed: 	9
# Tentative: 	7
# Rejected: 	434
# Iteration: 	40 / 100
# Confirmed: 	11
# Tentative: 	5
# Rejected: 	434
# Iteration: 	41 / 100
# Confirmed: 	11
# Tentative: 	5
# Rejected: 	434
# Iteration: 	42 / 100
# Confirmed: 	11
# Tentative: 	5
# Rejected: 	434
# Iteration: 	43 / 100
# Confirmed: 	12
# Tentative: 	4
# Rejected: 	434
# Iteration: 	44 / 100
# Confirmed: 	12
# Tentative: 	4
# Rejected: 	434
# Iteration: 	45 / 100
# Confirmed: 	12
# Tentative: 	4
# Rejected: 	434
# Iteration: 	46 / 100
# Confirmed: 	12
# Tentative: 	4
# Rejected: 	434
# Iteration: 	47 / 100
# Confirmed: 	12
# Tentative: 	4
# Rejected: 	434
# Iteration: 	48 / 100
# Confirmed: 	12
# Tentative: 	4
# Rejected: 	434
# Iteration: 	49 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	50 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	51 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	52 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	53 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	54 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	55 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	56 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	57 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	58 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	59 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	60 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	61 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	62 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	63 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	64 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	65 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	66 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	67 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	68 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	69 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	70 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	71 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	72 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	73 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	74 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	75 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	76 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	77 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	78 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	79 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	80 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	81 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	82 / 100
# Confirmed: 	13
# Tentative: 	3
# Rejected: 	434
# Iteration: 	83 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	84 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	85 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	86 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	87 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	88 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	89 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	90 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	91 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	92 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	93 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	94 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	95 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	96 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	97 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	98 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
# Iteration: 	99 / 100
# Confirmed: 	14
# Tentative: 	2
# Rejected: 	434
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	14
# Tentative: 	1
# Rejected: 	434
# Ranking:  [139 298 380 374 228 399 409 388 135 206  99 245 117 412  39 224 410 309
#  318  11   1 335 338  26  20  17 228 340 140 277 193  24 346 286 240 197
#    1 328  25 115 277 304 179 355 206 217 323  81 397 418  93 348 293 351
#    1 280  34  40  21   1   1 167 165 112  62  11 301 376 435 128 100 142
#  354 307 204  91 237 115 385 298 367 208 122 240 407 318 217 428 402 253
#  407 104 246 425  38  77  74 358 250 238 221 131 379  54 184 380  29 249
#  117 176  56 320  55  58 348 291 262 296 344 417 291  65 232 333 355 342
#  232 121 357 239 398 331 393 304 264 181 137 195 336  83   1  98 313  28
#   47 192 404 411  33  11   6 162 216  72 143  36 215 351 257 394 390 264
#  361 387 361 351 247 170 273 271  46 147 108  77 171  85  63 198 301  30
#  186  14 435 272 236 435  31  61  63 181  51 247 115 270 191 325  75 109
#  365 210  66 187 172 219 133 286  69  60 226 156 363 399 323 414   1 315
#  214 366 279 273 424 382 264 268 427 282 259 340 234 190 223 346  73   3
#  138 253 129  59 164 383 405   8   8  42 166 149  70 252 200  94 370 331
#  395 389 105 374 147 221 257 338 161 141 269  53  81 106  87 162  70  88
#  158 175  67 153   5 432 225 158 415 189 435   1  51 112 396  48 230 120
#  264 107 360 132 294 280 244  68 276 242 384 255 260 195 309 134  48 136
#  283 318 327 234 377  36 110 311 390 226 123 155 367 183 288 326 202 289
#  315 125 154 176 416 101   1 187 351  26  35  31 412 157  45  18  43  97
#  168 338 200   1 185 311 211 283 330 329 423 267 363 426 243 194 125 334
#    1 124 261  57 250 145  90 160 130   4 178   7 435 344 295 321 344 321
#  385 402 372 169 402 219 232 119  86 208 174  80 419 152  16 206 358 103
#  407 199 144 300 291 369 371   1 212 213 422 429 431 430 372 392 303 257
#   96  41 420  79  43 179 149  23   1 286 307 173   1 420  19  13  14   2
#   22  50 110 307 377  77 297 151  88  83  95 127 102 147 275  91 202 315]
# No. of significant features:  14
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\MPMD\SEM 2\eMPMD_2.2_Advanced_Data_Analytics\00 Assignment\Secom-Assignment-1\Secom-Assignment-1\Boruta_LatestFill_2.ipynb Cell 7' in <cell line: 20>()
#      <a href='vscode-notebook-cell:/d%3A/MPMD/SEM%202/eMPMD_2.2_Advanced_Data_Analytics/00%20Assignment/Secom-Assignment-1/Secom-Assignment-1/Boruta_LatestFill_2.ipynb#ch0000006?line=15'>16</a> # Using the BorutaPy object to transform the features in the dataset.
#      <a href='vscode-notebook-cell:/d%3A/MPMD/SEM%202/eMPMD_2.2_Advanced_Data_Analytics/00%20Assignment/Secom-Assignment-1/Secom-Assignment-1/Boruta_LatestFill_2.ipynb#ch0000006?line=17'>18</a> X_Filtered_train = boruta_selector.transform(np.array(x_train_LastFill2))
# ---> <a href='vscode-notebook-cell:/d%3A/MPMD/SEM%202/eMPMD_2.2_Advanced_Data_Analytics/00%20Assignment/Secom-Assignment-1/Secom-Assignment-1/Boruta_LatestFill_2.ipynb#ch0000006?line=19'>20</a> X_Filtered_test = boruta_selector.transform(np.array(x_test_LastFill2))
#
# File c:\Users\divya\anaconda3\lib\site-packages\boruta\boruta_py.py:222, in BorutaPy.transform(self, X, weak)
#     203 def transform(self, X, weak=False):
#     204     """
#     205     Reduces the input X to the features selected by Boruta.
#     206
#    (...)
#     219         selected by Boruta.
#     220     """
# --> 222     return self._transform(X, weak)
#
# File c:\Users\divya\anaconda3\lib\site-packages\boruta\boruta_py.py:368, in BorutaPy._transform(self, X, weak)
#     366     X = X[:, self.support_ + self.support_weak_]
#     367 else:
# --> 368     X = X[:, self.support_]
#     369 return X
#
# IndexError: boolean index did not match indexed array along dimension 1; dimension is 590 but corresponding boolean dimension is 450

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
#from sklearn.metrics import scorer
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import GridSearchCV 
from sklearn.model_selection import RandomizedSearchCV

classifiers = [['RandomForest :',RandomForestClassifier()]]

for name,classifier in classifiers:
    clf=classifier.fit(X_Filtered_train,y_train)
    y_pred=classifier.predict(X_Filtered_test)
    print(f'\n {name} \n')
    print(f'Training Score for {name}  {clf.score(X_Filtered_train,y_train) * 100:.2f}' )
    print(f'Testing Score for {name} {clf.score(X_Filtered_test,y_test) * 100:.2f}' )
    print(f'Classification report  \n {classification_report(y_test,y_pred)}' )
    print(f'Confusion matrix  \n {confusion_matrix(y_test,y_pred)}' )
    print(f'ROC AUC  : {roc_auc_score(y_test,y_pred)}' )
